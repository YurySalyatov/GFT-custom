# %%
# !git clone https://github.com/yurysalyatov/gft-custom.git
# Out:
# Cloning into 'gft-custom'...
# remote: Enumerating objects: 472, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 472 (delta 71), reused 74 (delta 32), pack-reused 347 (from 1)
# Receiving objects: 100% (472/472), 1.45 GiB | 33.92 MiB/s, done.
# Resolving deltas: 100% (141/141), done.
# Updating files: 100% (126/126), done.

# %%
# %cd gft-custom
# Out:
# /kaggle/working/gft-custom

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !nvidia-smi
# Out:
# Wed Aug  5 14:17:54 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   49C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Установка PyTorch с CUDA
# !pip install torch --index-url https://download.pytorch.org/whl/cu128

# Установка PyTorch Geometric
import torch
print(torch.__version__)
import os
os.environ['TORCH'] = torch.__version__

# !pip install torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install pyg-lib -f https://data.pyg.org/whl/nightly/torch-${TORCH}.html
# !pip install git+https://github.com/pyg-team/pytorch_geometric.git

# Установка остальных зависимостей из requirements.txt
# !pip install -r requirements.txt

# Проверка установки
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# 2.10.0+cu128
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcu128/torch_scatter-2.1.2%2Bpt210cu128-cp312-cp312-linux_x86_64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 96.0 MB/s eta 0:00:00
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.1.2+pt210cu128
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcu128/torch_sparse-0.6.18%2Bpt210cu128-cp312-cp312-linux_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 66.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from torch-sparse) (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from scipy->torch-sparse) (2.0.2)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.18+pt210cu128
# Looking in links: https://data.pyg.org/whl/nightly/torch-2.10.0+cu128.html
# Collecting pyg-lib
#   Downloading https://data.pyg.org/whl/nightly/torch-2.10.0%2Bcu128/pyg_lib-0.8.0.dev20260721%2Bpt210cu128-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 64.6 MB/s eta 0:00:00
# Installing collected packages: pyg-lib
# Successfully installed pyg-lib-0.8.0.dev20260721+pt210cu128
# Collecting git+https://github.com/pyg-team/pytorch_geometric.git
#   Cloning https://github.com/pyg-team/pytorch_geometric.git to /tmp/pip-req-build-4n1xdtnl
#   Running command git clone --filter=blob:none --quiet https://github.com/pyg-team/pytorch_geometric.git /tmp/pip-req-build-4n1xdtnl
#   Resolved https://github.com/pyg-team/pytorch_geometric.git to commit cc678a392255a1467872f54582724b8dce434603
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.9.0) (3.13.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.9.0) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.9.0) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.9.0) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.9.0) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.9.0) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.9.0) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.9.0) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.9.0) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.9.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.9.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.9.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.9.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.9.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.9.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.9.0) (1.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch-geometric==2.9.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.9.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.9.0) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.9.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.9.0) (2026.4.22)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch-geometric==2.9.0) (4.15.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (pyproject.toml) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.9.0-py3-none-any.whl size=1328695 sha256=836c8208fd22a9d0463ad7ecde760996bb587d09ed963b4d8c4a7ab7f0dbe7d0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ta8_87uv/wheels/96/ab/80/5e43250505a6e639df59a3d89c6b45ed5511f70db8d0ac39c7
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.9.0
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (3.6.1)
# Requirement already satisfied: tqdm>=4.65 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (4.67.3)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: wandb>=0.14 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.26.1)
# Collecting ogb>=1.3.6 (from -r requirements.txt (line 10))
#   Downloading ogb-1.3.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: sentence-transformers>=2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (5.4.1)
# Requirement already satisfied: transformers>=4.36 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (5.0.0)
# Requirement already satisfied: datasets>=2.16 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (5.0.0)
# Requirement already satisfied: accelerate>=0.25 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (1.13.0)
# Requirement already satisfied: einops>=0.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (0.8.2)
# Collecting hjson>=3.1 (from -r requirements.txt (line 16))
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting lightning>=2.0 (from -r requirements.txt (line 17))
#   Downloading lightning-2.6.5-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.1 MB/s eta 0:00:00
# Collecting rdkit (from -r requirements.txt (line 18))
#   Downloading rdkit-2026.3.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->-r requirements.txt (line 3)) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2->-r requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 5)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 5)) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.14->-r requirements.txt (line 9)) (8.3.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.14->-r requirements.txt (line 9)) (3.1.47)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.14->-r requirements.txt (line 9)) (4.9.6)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.14->-r requirements.txt (line 9)) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.14->-r requirements.txt (line 9)) (2.12.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.14->-r requirements.txt (line 9)) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.14->-r requirements.txt (line 9)) (2.58.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.14->-r requirements.txt (line 9)) (4.15.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from ogb>=1.3.6->-r requirements.txt (line 10)) (2.10.0+cu128)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from ogb>=1.3.6->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: urllib3>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from ogb>=1.3.6->-r requirements.txt (line 10)) (2.5.0)
# Collecting outdated>=0.2.0 (from ogb>=1.3.6->-r requirements.txt (line 10))
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.2->-r requirements.txt (line 11)) (1.11.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 12)) (3.29.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 12)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 12)) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 12)) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16->-r requirements.txt (line 13)) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16->-r requirements.txt (line 13)) (0.4.1)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16->-r requirements.txt (line 13)) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16->-r requirements.txt (line 13)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.16->-r requirements.txt (line 13)) (0.70.16)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=2.16->-r requirements.txt (line 13)) (2025.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.25->-r requirements.txt (line 14)) (5.9.5)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->-r requirements.txt (line 17)) (0.15.3)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->-r requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->-r requirements.txt (line 17)) (2.6.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=2.16->-r requirements.txt (line 13)) (3.13.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.14->-r requirements.txt (line 9)) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.16->-r requirements.txt (line 13)) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.16->-r requirements.txt (line 13)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.16->-r requirements.txt (line 13)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.16->-r requirements.txt (line 13)) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.16->-r requirements.txt (line 13)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.2->-r requirements.txt (line 11)) (1.4.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.2->-r requirements.txt (line 11)) (0.24.2)
# Requirement already satisfied: setuptools>=44 in /usr/local/lib/python3.12/dist-packages (from outdated>=0.2.0->ogb>=1.3.6->-r requirements.txt (line 10)) (81.0.0)
# Collecting littleutils (from outdated>=0.2.0->ogb>=1.3.6->-r requirements.txt (line 10))
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.14->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.14->-r requirements.txt (line 9)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.14->-r requirements.txt (line 9)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb>=0.14->-r requirements.txt (line 9)) (3.4.7)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (1.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=2.16->-r requirements.txt (line 13)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=2.16->-r requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=2.16->-r requirements.txt (line 13)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=2.16->-r requirements.txt (line 13)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=2.16->-r requirements.txt (line 13)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=2.16->-r requirements.txt (line 13)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=2.16->-r requirements.txt (line 13)) (1.23.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.14->-r requirements.txt (line 9)) (5.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2->-r requirements.txt (line 11)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2->-r requirements.txt (line 11)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2->-r requirements.txt (line 11)) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6.0->ogb>=1.3.6->-r requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2->-r requirements.txt (line 11)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2->-r requirements.txt (line 11)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.23.0->sentence-transformers>=2.2->-r requirements.txt (line 11)) (0.1.2)
# Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 5.9 MB/s eta 0:00:00
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.5 MB/s eta 0:00:00
# Downloading lightning-2.6.5-py3-none-any.whl (848 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 27.6 MB/s eta 0:00:00
# Downloading rdkit-2026.3.5-cp312-cp312-manylinux_2_28_x86_64.whl (37.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.4/37.4 MB 52.5 MB/s eta 0:00:00
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Installing collected packages: hjson, rdkit, littleutils, outdated, ogb, lightning
# Successfully installed hjson-3.1.0 lightning-2.6.5 littleutils-0.2.4 ogb-1.3.6 outdated-0.2.2 rdkit-2026.3.5
# 2.10.0+cu128
# True

# %%
# !pip install lightning

# %%
# !pip install rdkit

# %%
# !ls
# Out:
#  assets			  environment.yml	     requirements.txt
#  change_yaml_config.py	  GFT			     script
#  ckpts			  GFT_run.ipynb		     test.py
#  config			  LICENSE		     utils.py
#  data			  notebook55ba2ff0a6.ipynb  'диаграмма процесса.jpg'
#  embeddings_by_type.npz   process_datasets.py
#  embeddings_by_type.pkl   README.md

# %%
# import os

# # Точный путь к данным (проверьте, что внутри есть папка data или сразу файлы)
# source_path = "/kaggle/input/datasets/yurysalyatov/gft-data/data"

# # Если в рабочей директории уже есть папка или ссылка с именем "data" – удаляем
# if os.path.exists("data"):
#     !rm -rf data   # осторожно, но безопасно, т.к. это только ссылка или локальная папка

# # Создаём символическую ссылку (флаг -sf: перезапись, если есть)
# !ln -sf {source_path} data

# # Проверяем, что ссылка работает – должны увидеть содержимое ваших данных
# !ls -la data

# %%
import os

# Точный путь к данным (проверьте, что внутри есть папка data или сразу файлы)
source_path = "/kaggle/input/datasets/yurysalyatov/graph-dir/graph_dir"

# Если в рабочей директории уже есть папка или ссылка с именем "graph_dir" – удаляем
if os.path.exists("graph_dir"):
    # !rm -rf graph_dir   # осторожно, но безопасно, т.к. это только ссылка или локальная папка

# Создаём символическую ссылку (флаг -sf: перезапись, если есть)
# !ln -sf {source_path} graph_dir

# Проверяем, что ссылка работает – должны увидеть содержимое ваших данных
# !ls -la graph_dir
# Out:
# lrwxrwxrwx 1 root root 55 Aug  5 14:18 graph_dir -> /kaggle/input/datasets/yurysalyatov/graph-dir/graph_dir

# %%
# Предобработка всех шести датасетов
# !python process_datasets.py --datasets aminer,arnetminer,kisti,pbmed,qian,zbmath
# Out:
# /kaggle/working/gft-custom/kaggle/working/gft-custom/graph_dir/
# Data(x=[341106], edge_index=[2, 426635], node_text_feat=[341106, 768], edge_text_feat=[4, 768], xe=[426635], node_type_onehot=[341106, 4], edge_attr_onehot=[426635, 4])
# Data(x=[17050], edge_index=[2, 23460], node_text_feat=[17050, 768], edge_text_feat=[4, 768], xe=[23460], node_type_onehot=[17050, 4], edge_attr_onehot=[23460, 4])
# Data(x=[81812], edge_index=[2, 156943], node_text_feat=[81812, 768], edge_text_feat=[4, 768], xe=[156943], node_type_onehot=[81812, 4], edge_attr_onehot=[156943, 4])
# Data(x=[8976], edge_index=[2, 9854], node_text_feat=[8976, 768], edge_text_feat=[4, 768], xe=[9854], node_type_onehot=[8976, 4], edge_attr_onehot=[9854, 4])
# Data(x=[15929], edge_index=[2, 21582], node_text_feat=[15929, 768], edge_text_feat=[4, 768], xe=[21582], node_type_onehot=[15929, 4], edge_attr_onehot=[21582, 4])
# Data(x=[28659], edge_index=[2, 26614], node_text_feat=[28659, 768], edge_text_feat=[4, 768], xe=[26614], node_type_onehot=[28659, 4], edge_attr_onehot=[26614, 4])

# %%
import itertools
import os

all_datasets = ['aminer', 'arnetminer', 'kisti', 'pbmed', 'qian', 'zbmath']
# all_datasets = ['arnetminer', 'pbmed', 'qian', 'zbmath']
# Генерируем все непустые подмножества (2^6 - 1 = 63)
dataset_sets = []
for r in range(1, len(all_datasets) + 1):
    for combo in itertools.combinations(all_datasets, r):
        dataset_sets.append(list(combo))

print(f"Всего наборов: {len(dataset_sets)}")
# Для отладки выведем первые 5
for i, s in enumerate(dataset_sets[:5]):
    print(f"{i+1}: {s}")
# dataset_sets = dataset_sets[:5]
# dataset_sets = dataset_sets[5:10]
# dataset_sets = dataset_sets[10:15]
# dataset_sets = dataset_sets[15:20]
dataset_sets = dataset_sets[-8:]
# Out:
# Всего наборов: 63
# 1: ['aminer']
# 2: ['arnetminer']
# 3: ['kisti']
# 4: ['pbmed']
# 5: ['qian']

# %%
import os
import shutil
import time

base_ckpt = 'ckpts/pretrain_model'
embeddings_root = 'embeddings'
epoch_to_load = 50  # эпоха, которую будем использовать для извлечения (можно менять)

# Создаём корневые папки
os.makedirs(base_ckpt, exist_ok=True)
os.makedirs(embeddings_root, exist_ok=True)

for idx, dataset_list in enumerate(dataset_sets):
    set_name = '_'.join(dataset_list)  # например "arnetminer_qian"
    print(f"\n=== Обработка набора {idx+1}/{len(dataset_sets)}: {set_name} ===")
    start_time = time.time()

    # 1. Обновляем конфиг для обучения
    # !python change_yaml_config.py --datasets {','.join(dataset_list)} --config config/pt_data.yaml --default_weight 1.0

    # 2. Запускаем предобучение с сохранением в отдельную папку
    save_dir = f"{base_ckpt}/"
    # !mkdir -p {save_dir}
    # !python GFT/pretrain.py --use_params --debug --save_dir {save_dir} --save_name {set_name}
    
    checkpoint_folder = f"{base_ckpt}/codebook_size_128_layer_2_pretrain_on_{set_name}_seed_42"
    dst_model = f"{embeddings_root}/{set_name}/codebook_size_128_layer_2_pretrain_on_{set_name}_seed_42"
    encoder = f"{checkpoint_folder}/encoder_{epoch_to_load}.pt"
    vq = f"{checkpoint_folder}/vq_{epoch_to_load}.pt"
    os.makedirs(dst_model, exist_ok=True)
    shutil.move(encoder, f"{dst_model}/encoder_{epoch_to_load}.pt")
    shutil.move(vq, f"{dst_model}/vq_{epoch_to_load}.pt")
    info_file = f"{checkpoint_folder}/info.txt"
    if os.path.exists(info_file):
        shutil.move(info_file, f"{dst_model}/info.txt")
    shutil.rmtree(checkpoint_folder)
    # 3. Извлекаем эмбеддинги для ВСЕХ датасетов (из all_datasets)
    for ds in all_datasets:
        print(f"  Извлечение для {ds}...")
        out_dir = f"{embeddings_root}/{set_name}/{ds}"
        # !python GFT/extract_embs.py --dataset {ds} --checkpoint_dir {dst_model} --epoch {epoch_to_load} --output_dir {out_dir}

    elapsed = time.time() - start_time
    print(f"Набор {set_name} завершён за {elapsed:.2f} сек.")

print("Все наборы обработаны.")
# Out:
# === Обработка набора 1/8: kisti_pbmed_qian_zbmath ===
# Updated 'all' section in config/pt_data.yaml with datasets: ['kisti', 'pbmed', 'qian', 'zbmath']
# New 'all' content:
#   kisti: 1.0
#   pbmed: 1.0
#   qian: 1.0
#   zbmath: 1.0
# /kaggle/working/gft-custom/GFT/dataset
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Pre-training on ['kisti', 'pbmed', 'qian', 'zbmath']
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 1.
# /kaggle/working/gft-custom/GFT/pretrain.py:42: UserWarning: 'dropout_adj' is deprecated, use 'dropout_edge' instead
#   aug_edge_index, aug_edge_attr = dropout_adj(
# Info saved to ckpts/pretrain_model/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42/info.txt
# Save the model at epoch 1
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 2.
# Save the model at epoch 2
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 3.
# Save the model at epoch 3
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 4.
# Save the model at epoch 4
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 5.
# Save the model at epoch 5
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 6.
# Save the model at epoch 6
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 7.
# Save the model at epoch 7
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 8.
# Save the model at epoch 8
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 9.
# Save the model at epoch 9
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 10.
# Save the model at epoch 10
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 11.
# Save the model at epoch 11
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 12.
# Save the model at epoch 12
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 13.
# Save the model at epoch 13
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 14.
# Save the model at epoch 14
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 15.
# Save the model at epoch 15
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 16.
# Save the model at epoch 16
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 17.
# Save the model at epoch 17
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 18.
# Save the model at epoch 18
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 19.
# Save the model at epoch 19
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 20.
# Save the model at epoch 20
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 21.
# Save the model at epoch 21
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 22.
# Save the model at epoch 22
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 23.
# Save the model at epoch 23
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 24.
# Save the model at epoch 24
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 25.
# Save the model at epoch 25
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 26.
# Save the model at epoch 26
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 27.
# Save the model at epoch 27
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 28.
# Save the model at epoch 28
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 29.
# Save the model at epoch 29
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 30.
# Save the model at epoch 30
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 31.
# Save the model at epoch 31
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 32.
# Save the model at epoch 32
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 33.
# Save the model at epoch 33
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 34.
# Save the model at epoch 34
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 35.
# Save the model at epoch 35
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 36.
# Save the model at epoch 36
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 37.
# Save the model at epoch 37
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 38.
# Save the model at epoch 38
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 39.
# Save the model at epoch 39
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 40.
# Save the model at epoch 40
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 41.
# Save the model at epoch 41
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 42.
# Save the model at epoch 42
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 43.
# Save the model at epoch 43
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 44.
# Save the model at epoch 44
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 45.
# Save the model at epoch 45
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 46.
# Save the model at epoch 46
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 47.
# Save the model at epoch 47
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 48.
# Save the model at epoch 48
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 49.
# Save the model at epoch 49
# Number of training nodes is 135376
# Number of mini-batches is 133 at epoch 50.
# Save the model at epoch 50
#   Извлечение для aminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph aminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████| 334/334 [00:14<00:00, 22.32it/s]
# Saved to embeddings/kisti_pbmed_qian_zbmath/aminer
# Type 'author': 157448 nodes, dim 768
#   Извлечение для arnetminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph arnetminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 17/17 [00:00<00:00, 17.36it/s]
# Saved to embeddings/kisti_pbmed_qian_zbmath/arnetminer
# Type 'author': 7144 nodes, dim 768
#   Извлечение для kisti...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph kisti...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 80/80 [00:04<00:00, 18.78it/s]
# Saved to embeddings/kisti_pbmed_qian_zbmath/kisti
# Type 'author': 40383 nodes, dim 768
#   Извлечение для pbmed...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph pbmed...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████████| 9/9 [00:00<00:00, 15.82it/s]
# Saved to embeddings/kisti_pbmed_qian_zbmath/pbmed
# Type 'author': 2871 nodes, dim 768
#   Извлечение для qian...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph qian...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 16/16 [00:00<00:00, 17.62it/s]
# Saved to embeddings/kisti_pbmed_qian_zbmath/qian
# Type 'author': 6542 nodes, dim 768
#   Извлечение для zbmath...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph zbmath...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 28/28 [00:01<00:00, 21.03it/s]
# Saved to embeddings/kisti_pbmed_qian_zbmath/zbmath
# Type 'author': 15181 nodes, dim 768
# Набор kisti_pbmed_qian_zbmath завершён за 604.64 сек.
#
# === Обработка набора 2/8: aminer_arnetminer_kisti_pbmed_qian ===
# Updated 'all' section in config/pt_data.yaml with datasets: ['aminer', 'arnetminer', 'kisti', 'pbmed', 'qian']
# New 'all' content:
#   aminer: 1.0
#   arnetminer: 1.0
#   kisti: 1.0
#   pbmed: 1.0
#   qian: 1.0
# /kaggle/working/gft-custom/GFT/dataset
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Pre-training on ['aminer', 'arnetminer', 'kisti', 'pbmed', 'qian']
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 1.
# /kaggle/working/gft-custom/GFT/pretrain.py:42: UserWarning: 'dropout_adj' is deprecated, use 'dropout_edge' instead
#   aug_edge_index, aug_edge_attr = dropout_adj(
# Info saved to ckpts/pretrain_model/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42/info.txt
# Save the model at epoch 1
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 2.
# Save the model at epoch 2
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 3.
# Save the model at epoch 3
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 4.
# Save the model at epoch 4
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 5.
# Save the model at epoch 5
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 6.
# Save the model at epoch 6
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 7.
# Save the model at epoch 7
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 8.
# Save the model at epoch 8
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 9.
# Save the model at epoch 9
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 10.
# Save the model at epoch 10
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 11.
# Save the model at epoch 11
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 12.
# Save the model at epoch 12
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 13.
# Save the model at epoch 13
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 14.
# Save the model at epoch 14
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 15.
# Save the model at epoch 15
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 16.
# Save the model at epoch 16
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 17.
# Save the model at epoch 17
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 18.
# Save the model at epoch 18
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 19.
# Save the model at epoch 19
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 20.
# Save the model at epoch 20
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 21.
# Save the model at epoch 21
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 22.
# Save the model at epoch 22
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 23.
# Save the model at epoch 23
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 24.
# Save the model at epoch 24
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 25.
# Save the model at epoch 25
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 26.
# Save the model at epoch 26
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 27.
# Save the model at epoch 27
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 28.
# Save the model at epoch 28
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 29.
# Save the model at epoch 29
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 30.
# Save the model at epoch 30
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 31.
# Save the model at epoch 31
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 32.
# Save the model at epoch 32
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 33.
# Save the model at epoch 33
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 34.
# Save the model at epoch 34
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 35.
# Save the model at epoch 35
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 36.
# Save the model at epoch 36
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 37.
# Save the model at epoch 37
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 38.
# Save the model at epoch 38
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 39.
# Save the model at epoch 39
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 40.
# Save the model at epoch 40
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 41.
# Save the model at epoch 41
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 42.
# Save the model at epoch 42
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 43.
# Save the model at epoch 43
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 44.
# Save the model at epoch 44
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 45.
# Save the model at epoch 45
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 46.
# Save the model at epoch 46
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 47.
# Save the model at epoch 47
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 48.
# Save the model at epoch 48
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 49.
# Save the model at epoch 49
# Number of training nodes is 464873
# Number of mini-batches is 454 at epoch 50.
# Save the model at epoch 50
#   Извлечение для aminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42, epoch 50
# Loading graph aminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████| 334/334 [00:14<00:00, 22.39it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian/aminer
# Type 'author': 157448 nodes, dim 768
#   Извлечение для arnetminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42, epoch 50
# Loading graph arnetminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 17/17 [00:00<00:00, 18.05it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian/arnetminer
# Type 'author': 7144 nodes, dim 768
#   Извлечение для kisti...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42, epoch 50
# Loading graph kisti...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 80/80 [00:04<00:00, 19.40it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian/kisti
# Type 'author': 40383 nodes, dim 768
#   Извлечение для pbmed...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42, epoch 50
# Loading graph pbmed...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████████| 9/9 [00:00<00:00, 15.60it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian/pbmed
# Type 'author': 2871 nodes, dim 768
#   Извлечение для qian...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42, epoch 50
# Loading graph qian...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 16/16 [00:00<00:00, 17.59it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian/qian
# Type 'author': 6542 nodes, dim 768
#   Извлечение для zbmath...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42, epoch 50
# Loading graph zbmath...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 28/28 [00:01<00:00, 20.51it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian/zbmath
# Type 'author': 15181 nodes, dim 768
# Набор aminer_arnetminer_kisti_pbmed_qian завершён за 1497.90 сек.
#
# === Обработка набора 3/8: aminer_arnetminer_kisti_pbmed_zbmath ===
# Updated 'all' section in config/pt_data.yaml with datasets: ['aminer', 'arnetminer', 'kisti', 'pbmed', 'zbmath']
# New 'all' content:
#   aminer: 1.0
#   arnetminer: 1.0
#   kisti: 1.0
#   pbmed: 1.0
#   zbmath: 1.0
# /kaggle/working/gft-custom/GFT/dataset
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Pre-training on ['aminer', 'arnetminer', 'kisti', 'pbmed', 'zbmath']
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 1.
# /kaggle/working/gft-custom/GFT/pretrain.py:42: UserWarning: 'dropout_adj' is deprecated, use 'dropout_edge' instead
#   aug_edge_index, aug_edge_attr = dropout_adj(
# Info saved to ckpts/pretrain_model/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42/info.txt
# Save the model at epoch 1
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 2.
# Save the model at epoch 2
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 3.
# Save the model at epoch 3
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 4.
# Save the model at epoch 4
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 5.
# Save the model at epoch 5
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 6.
# Save the model at epoch 6
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 7.
# Save the model at epoch 7
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 8.
# Save the model at epoch 8
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 9.
# Save the model at epoch 9
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 10.
# Save the model at epoch 10
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 11.
# Save the model at epoch 11
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 12.
# Save the model at epoch 12
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 13.
# Save the model at epoch 13
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 14.
# Save the model at epoch 14
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 15.
# Save the model at epoch 15
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 16.
# Save the model at epoch 16
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 17.
# Save the model at epoch 17
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 18.
# Save the model at epoch 18
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 19.
# Save the model at epoch 19
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 20.
# Save the model at epoch 20
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 21.
# Save the model at epoch 21
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 22.
# Save the model at epoch 22
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 23.
# Save the model at epoch 23
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 24.
# Save the model at epoch 24
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 25.
# Save the model at epoch 25
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 26.
# Save the model at epoch 26
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 27.
# Save the model at epoch 27
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 28.
# Save the model at epoch 28
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 29.
# Save the model at epoch 29
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 30.
# Save the model at epoch 30
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 31.
# Save the model at epoch 31
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 32.
# Save the model at epoch 32
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 33.
# Save the model at epoch 33
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 34.
# Save the model at epoch 34
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 35.
# Save the model at epoch 35
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 36.
# Save the model at epoch 36
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 37.
# Save the model at epoch 37
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 38.
# Save the model at epoch 38
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 39.
# Save the model at epoch 39
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 40.
# Save the model at epoch 40
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 41.
# Save the model at epoch 41
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 42.
# Save the model at epoch 42
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 43.
# Save the model at epoch 43
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 44.
# Save the model at epoch 44
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 45.
# Save the model at epoch 45
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 46.
# Save the model at epoch 46
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 47.
# Save the model at epoch 47
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 48.
# Save the model at epoch 48
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 49.
# Save the model at epoch 49
# Number of training nodes is 477603
# Number of mini-batches is 467 at epoch 50.
# Save the model at epoch 50
#   Извлечение для aminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42, epoch 50
# Loading graph aminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████| 334/334 [00:15<00:00, 22.18it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_zbmath/aminer
# Type 'author': 157448 nodes, dim 768
#   Извлечение для arnetminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42, epoch 50
# Loading graph arnetminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 17/17 [00:00<00:00, 19.05it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_zbmath/arnetminer
# Type 'author': 7144 nodes, dim 768
#   Извлечение для kisti...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42, epoch 50
# Loading graph kisti...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 80/80 [00:04<00:00, 19.55it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_zbmath/kisti
# Type 'author': 40383 nodes, dim 768
#   Извлечение для pbmed...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42, epoch 50
# Loading graph pbmed...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████████| 9/9 [00:00<00:00, 16.33it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_zbmath/pbmed
# Type 'author': 2871 nodes, dim 768
#   Извлечение для qian...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42, epoch 50
# Loading graph qian...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 16/16 [00:00<00:00, 18.89it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_zbmath/qian
# Type 'author': 6542 nodes, dim 768
#   Извлечение для zbmath...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42, epoch 50
# Loading graph zbmath...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 28/28 [00:01<00:00, 20.70it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_zbmath/zbmath
# Type 'author': 15181 nodes, dim 768
# Набор aminer_arnetminer_kisti_pbmed_zbmath завершён за 1518.98 сек.
#
# === Обработка набора 4/8: aminer_arnetminer_kisti_qian_zbmath ===
# Updated 'all' section in config/pt_data.yaml with datasets: ['aminer', 'arnetminer', 'kisti', 'qian', 'zbmath']
# New 'all' content:
#   aminer: 1.0
#   arnetminer: 1.0
#   kisti: 1.0
#   qian: 1.0
#   zbmath: 1.0
# /kaggle/working/gft-custom/GFT/dataset
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Pre-training on ['aminer', 'arnetminer', 'kisti', 'qian', 'zbmath']
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 1.
# /kaggle/working/gft-custom/GFT/pretrain.py:42: UserWarning: 'dropout_adj' is deprecated, use 'dropout_edge' instead
#   aug_edge_index, aug_edge_attr = dropout_adj(
# Info saved to ckpts/pretrain_model/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42/info.txt
# Save the model at epoch 1
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 2.
# Save the model at epoch 2
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 3.
# Save the model at epoch 3
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 4.
# Save the model at epoch 4
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 5.
# Save the model at epoch 5
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 6.
# Save the model at epoch 6
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 7.
# Save the model at epoch 7
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 8.
# Save the model at epoch 8
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 9.
# Save the model at epoch 9
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 10.
# Save the model at epoch 10
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 11.
# Save the model at epoch 11
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 12.
# Save the model at epoch 12
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 13.
# Save the model at epoch 13
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 14.
# Save the model at epoch 14
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 15.
# Save the model at epoch 15
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 16.
# Save the model at epoch 16
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 17.
# Save the model at epoch 17
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 18.
# Save the model at epoch 18
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 19.
# Save the model at epoch 19
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 20.
# Save the model at epoch 20
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 21.
# Save the model at epoch 21
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 22.
# Save the model at epoch 22
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 23.
# Save the model at epoch 23
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 24.
# Save the model at epoch 24
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 25.
# Save the model at epoch 25
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 26.
# Save the model at epoch 26
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 27.
# Save the model at epoch 27
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 28.
# Save the model at epoch 28
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 29.
# Save the model at epoch 29
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 30.
# Save the model at epoch 30
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 31.
# Save the model at epoch 31
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 32.
# Save the model at epoch 32
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 33.
# Save the model at epoch 33
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 34.
# Save the model at epoch 34
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 35.
# Save the model at epoch 35
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 36.
# Save the model at epoch 36
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 37.
# Save the model at epoch 37
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 38.
# Save the model at epoch 38
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 39.
# Save the model at epoch 39
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 40.
# Save the model at epoch 40
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 41.
# Save the model at epoch 41
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 42.
# Save the model at epoch 42
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 43.
# Save the model at epoch 43
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 44.
# Save the model at epoch 44
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 45.
# Save the model at epoch 45
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 46.
# Save the model at epoch 46
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 47.
# Save the model at epoch 47
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 48.
# Save the model at epoch 48
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 49.
# Save the model at epoch 49
# Number of training nodes is 484556
# Number of mini-batches is 474 at epoch 50.
# Save the model at epoch 50
#   Извлечение для aminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42, epoch 50
# Loading graph aminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████| 334/334 [00:14<00:00, 22.63it/s]
# Saved to embeddings/aminer_arnetminer_kisti_qian_zbmath/aminer
# Type 'author': 157448 nodes, dim 768
#   Извлечение для arnetminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42, epoch 50
# Loading graph arnetminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 17/17 [00:00<00:00, 17.98it/s]
# Saved to embeddings/aminer_arnetminer_kisti_qian_zbmath/arnetminer
# Type 'author': 7144 nodes, dim 768
#   Извлечение для kisti...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42, epoch 50
# Loading graph kisti...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 80/80 [00:04<00:00, 19.41it/s]
# Saved to embeddings/aminer_arnetminer_kisti_qian_zbmath/kisti
# Type 'author': 40383 nodes, dim 768
#   Извлечение для pbmed...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42, epoch 50
# Loading graph pbmed...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████████| 9/9 [00:00<00:00, 15.47it/s]
# Saved to embeddings/aminer_arnetminer_kisti_qian_zbmath/pbmed
# Type 'author': 2871 nodes, dim 768
#   Извлечение для qian...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42, epoch 50
# Loading graph qian...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 16/16 [00:00<00:00, 17.73it/s]
# Saved to embeddings/aminer_arnetminer_kisti_qian_zbmath/qian
# Type 'author': 6542 nodes, dim 768
#   Извлечение для zbmath...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42, epoch 50
# Loading graph zbmath...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 28/28 [00:01<00:00, 21.35it/s]
# Saved to embeddings/aminer_arnetminer_kisti_qian_zbmath/zbmath
# Type 'author': 15181 nodes, dim 768
# Набор aminer_arnetminer_kisti_qian_zbmath завершён за 1542.05 сек.
#
# === Обработка набора 5/8: aminer_arnetminer_pbmed_qian_zbmath ===
# Updated 'all' section in config/pt_data.yaml with datasets: ['aminer', 'arnetminer', 'pbmed', 'qian', 'zbmath']
# New 'all' content:
#   aminer: 1.0
#   arnetminer: 1.0
#   pbmed: 1.0
#   qian: 1.0
#   zbmath: 1.0
# /kaggle/working/gft-custom/GFT/dataset
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Pre-training on ['aminer', 'arnetminer', 'pbmed', 'qian', 'zbmath']
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 1.
# /kaggle/working/gft-custom/GFT/pretrain.py:42: UserWarning: 'dropout_adj' is deprecated, use 'dropout_edge' instead
#   aug_edge_index, aug_edge_attr = dropout_adj(
# Info saved to ckpts/pretrain_model/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_pbmed_qian_zbmath_seed_42/info.txt
# Save the model at epoch 1
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 2.
# Save the model at epoch 2
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 3.
# Save the model at epoch 3
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 4.
# Save the model at epoch 4
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 5.
# Save the model at epoch 5
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 6.
# Save the model at epoch 6
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 7.
# Save the model at epoch 7
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 8.
# Save the model at epoch 8
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 9.
# Save the model at epoch 9
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 10.
# Save the model at epoch 10
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 11.
# Save the model at epoch 11
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 12.
# Save the model at epoch 12
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 13.
# Save the model at epoch 13
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 14.
# Save the model at epoch 14
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 15.
# Save the model at epoch 15
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 16.
# Save the model at epoch 16
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 17.
# Save the model at epoch 17
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 18.
# Save the model at epoch 18
# Number of training nodes is 411720
# Number of mini-batches is 403 at epoch 19.
# Save the model at epoch 19
# ...
# Loading graph aminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████| 334/334 [00:14<00:00, 22.57it/s]
# Saved to embeddings/arnetminer_kisti_pbmed_qian_zbmath/aminer
# Type 'author': 157448 nodes, dim 768
#   Извлечение для arnetminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph arnetminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 17/17 [00:00<00:00, 17.94it/s]
# Saved to embeddings/arnetminer_kisti_pbmed_qian_zbmath/arnetminer
# Type 'author': 7144 nodes, dim 768
#   Извлечение для kisti...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph kisti...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 80/80 [00:04<00:00, 19.15it/s]
# Saved to embeddings/arnetminer_kisti_pbmed_qian_zbmath/kisti
# Type 'author': 40383 nodes, dim 768
#   Извлечение для pbmed...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph pbmed...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████████| 9/9 [00:00<00:00, 15.37it/s]
# Saved to embeddings/arnetminer_kisti_pbmed_qian_zbmath/pbmed
# Type 'author': 2871 nodes, dim 768
#   Извлечение для qian...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph qian...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 16/16 [00:00<00:00, 17.72it/s]
# Saved to embeddings/arnetminer_kisti_pbmed_qian_zbmath/qian
# Type 'author': 6542 nodes, dim 768
#   Извлечение для zbmath...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph zbmath...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 28/28 [00:01<00:00, 21.13it/s]
# Saved to embeddings/arnetminer_kisti_pbmed_qian_zbmath/zbmath
# Type 'author': 15181 nodes, dim 768
# Набор arnetminer_kisti_pbmed_qian_zbmath завершён за 661.39 сек.
#
# === Обработка набора 8/8: aminer_arnetminer_kisti_pbmed_qian_zbmath ===
# Updated 'all' section in config/pt_data.yaml with datasets: ['aminer', 'arnetminer', 'kisti', 'pbmed', 'qian', 'zbmath']
# New 'all' content:
#   aminer: 1.0
#   arnetminer: 1.0
#   kisti: 1.0
#   pbmed: 1.0
#   qian: 1.0
#   zbmath: 1.0
# /kaggle/working/gft-custom/GFT/dataset
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Pre-training on ['aminer', 'arnetminer', 'kisti', 'pbmed', 'qian', 'zbmath']
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 1.
# /kaggle/working/gft-custom/GFT/pretrain.py:42: UserWarning: 'dropout_adj' is deprecated, use 'dropout_edge' instead
#   aug_edge_index, aug_edge_attr = dropout_adj(
# Info saved to ckpts/pretrain_model/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42/info.txt
# Save the model at epoch 1
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 2.
# Save the model at epoch 2
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 3.
# Save the model at epoch 3
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 4.
# Save the model at epoch 4
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 5.
# Save the model at epoch 5
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 6.
# Save the model at epoch 6
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 7.
# Save the model at epoch 7
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 8.
# Save the model at epoch 8
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 9.
# Save the model at epoch 9
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 10.
# Save the model at epoch 10
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 11.
# Save the model at epoch 11
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 12.
# Save the model at epoch 12
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 13.
# Save the model at epoch 13
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 14.
# Save the model at epoch 14
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 15.
# Save the model at epoch 15
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 16.
# Save the model at epoch 16
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 17.
# Save the model at epoch 17
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 18.
# Save the model at epoch 18
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 19.
# Save the model at epoch 19
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 20.
# Save the model at epoch 20
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 21.
# Save the model at epoch 21
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 22.
# Save the model at epoch 22
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 23.
# Save the model at epoch 23
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 24.
# Save the model at epoch 24
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 25.
# Save the model at epoch 25
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 26.
# Save the model at epoch 26
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 27.
# Save the model at epoch 27
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 28.
# Save the model at epoch 28
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 29.
# Save the model at epoch 29
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 30.
# Save the model at epoch 30
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 31.
# Save the model at epoch 31
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 32.
# Save the model at epoch 32
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 33.
# Save the model at epoch 33
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 34.
# Save the model at epoch 34
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 35.
# Save the model at epoch 35
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 36.
# Save the model at epoch 36
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 37.
# Save the model at epoch 37
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 38.
# Save the model at epoch 38
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 39.
# Save the model at epoch 39
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 40.
# Save the model at epoch 40
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 41.
# Save the model at epoch 41
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 42.
# Save the model at epoch 42
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 43.
# Save the model at epoch 43
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 44.
# Save the model at epoch 44
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 45.
# Save the model at epoch 45
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 46.
# Save the model at epoch 46
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 47.
# Save the model at epoch 47
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 48.
# Save the model at epoch 48
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 49.
# Save the model at epoch 49
# Number of training nodes is 493532
# Number of mini-batches is 482 at epoch 50.
# Save the model at epoch 50
#   Извлечение для aminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph aminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████| 334/334 [00:17<00:00, 19.25it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/aminer
# Type 'author': 157448 nodes, dim 768
#   Извлечение для arnetminer...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph arnetminer...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 17/17 [00:01<00:00, 15.98it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/arnetminer
# Type 'author': 7144 nodes, dim 768
#   Извлечение для kisti...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph kisti...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 80/80 [00:04<00:00, 17.18it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/kisti
# Type 'author': 40383 nodes, dim 768
#   Извлечение для pbmed...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph pbmed...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|██████████████████████| 9/9 [00:00<00:00, 13.82it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/pbmed
# Type 'author': 2871 nodes, dim 768
#   Извлечение для qian...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph qian...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 16/16 [00:00<00:00, 17.05it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/qian
# Type 'author': 6542 nodes, dim 768
#   Извлечение для zbmath...
# /kaggle/working/gft-custom/GFT/model/vq.py:438: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /kaggle/working/gft-custom/GFT/model/vq.py:623: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Loading model from embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42, epoch 50
# Loading graph zbmath...
# Extracting embeddings in batches...
# Extracting embeddings: 100%|████████████████████| 28/28 [00:01<00:00, 18.19it/s]
# Saved to embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/zbmath
# Type 'author': 15181 nodes, dim 768
# Набор aminer_arnetminer_kisti_pbmed_qian_zbmath завершён за 1597.94 сек.
# Все наборы обработаны.

# %%
# Упаковываем папку с эмбеддингами в zip-архив
# !zip -r /kaggle/working/embeddings_all.zip embeddings/
print("Архив embeddings_all.zip создан. Скачайте его через интерфейс Kaggle.")
# Out:
#   adding: embeddings/ (stored 0%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/ (stored 0%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/kisti/ (stored 0%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/kisti/kisti_embeddings.pkl (deflated 84%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42/ (stored 0%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42/info.txt (deflated 12%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42/vq_50.pt (deflated 8%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_kisti_pbmed_qian_zbmath_seed_42/encoder_50.pt (deflated 8%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/zbmath/ (stored 0%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/zbmath/zbmath_embeddings.pkl (deflated 77%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/qian/ (stored 0%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/qian/qian_embeddings.pkl (deflated 90%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/pbmed/ (stored 0%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/pbmed/pbmed_embeddings.pkl (deflated 87%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/aminer/ (stored 0%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/aminer/aminer_embeddings.pkl (deflated 94%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/arnetminer/ (stored 0%)
#   adding: embeddings/kisti_pbmed_qian_zbmath/arnetminer/arnetminer_embeddings.pkl (deflated 96%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/kisti/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/kisti/kisti_embeddings.pkl (deflated 82%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/zbmath/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/zbmath/zbmath_embeddings.pkl (deflated 77%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/qian/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/qian/qian_embeddings.pkl (deflated 90%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/pbmed/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/pbmed/pbmed_embeddings.pkl (deflated 86%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/aminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/aminer/aminer_embeddings.pkl (deflated 93%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42/info.txt (deflated 18%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42/vq_50.pt (deflated 8%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_seed_42/encoder_50.pt (deflated 8%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/arnetminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian/arnetminer/arnetminer_embeddings.pkl (deflated 96%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/ (stored 0%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/kisti/ (stored 0%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/kisti/kisti_embeddings.pkl (deflated 84%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/zbmath/ (stored 0%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/zbmath/zbmath_embeddings.pkl (deflated 76%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/qian/ (stored 0%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/qian/qian_embeddings.pkl (deflated 90%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/pbmed/ (stored 0%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/pbmed/pbmed_embeddings.pkl (deflated 86%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/aminer/ (stored 0%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/aminer/aminer_embeddings.pkl (deflated 94%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_arnetminer_kisti_pbmed_qian_zbmath_seed_42/ (stored 0%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_arnetminer_kisti_pbmed_qian_zbmath_seed_42/info.txt (deflated 16%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_arnetminer_kisti_pbmed_qian_zbmath_seed_42/vq_50.pt (deflated 8%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_arnetminer_kisti_pbmed_qian_zbmath_seed_42/encoder_50.pt (deflated 8%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/arnetminer/ (stored 0%)
#   adding: embeddings/arnetminer_kisti_pbmed_qian_zbmath/arnetminer/arnetminer_embeddings.pkl (deflated 96%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/kisti/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/kisti/kisti_embeddings.pkl (deflated 82%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/zbmath/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/zbmath/zbmath_embeddings.pkl (deflated 78%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/qian/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/qian/qian_embeddings.pkl (deflated 91%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/pbmed/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/pbmed/pbmed_embeddings.pkl (deflated 87%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/aminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/aminer/aminer_embeddings.pkl (deflated 93%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/arnetminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/arnetminer/arnetminer_embeddings.pkl (deflated 96%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_pbmed_qian_zbmath_seed_42/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_pbmed_qian_zbmath_seed_42/info.txt (deflated 16%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_pbmed_qian_zbmath_seed_42/vq_50.pt (deflated 8%)
#   adding: embeddings/aminer_arnetminer_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_pbmed_qian_zbmath_seed_42/encoder_50.pt (deflated 8%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/kisti/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/kisti/kisti_embeddings.pkl (deflated 82%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/zbmath/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/zbmath/zbmath_embeddings.pkl (deflated 78%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/qian/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/qian/qian_embeddings.pkl (deflated 90%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/pbmed/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/pbmed/pbmed_embeddings.pkl (deflated 86%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/aminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/aminer/aminer_embeddings.pkl (deflated 93%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/arnetminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/arnetminer/arnetminer_embeddings.pkl (deflated 96%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42/info.txt (deflated 17%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42/vq_50.pt (deflated 8%)
#   adding: embeddings/aminer_arnetminer_kisti_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_qian_zbmath_seed_42/encoder_50.pt (deflated 8%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/kisti/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/kisti/kisti_embeddings.pkl (deflated 83%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/zbmath/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/zbmath/zbmath_embeddings.pkl (deflated 77%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/qian/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/qian/qian_embeddings.pkl (deflated 90%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/pbmed/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/pbmed/pbmed_embeddings.pkl (deflated 86%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/aminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/aminer/aminer_embeddings.pkl (deflated 93%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/arnetminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/arnetminer/arnetminer_embeddings.pkl (deflated 97%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42/info.txt (deflated 17%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42/vq_50.pt (deflated 8%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_zbmath_seed_42/encoder_50.pt (deflated 8%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/kisti/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/kisti/kisti_embeddings.pkl (deflated 82%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/zbmath/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/zbmath/zbmath_embeddings.pkl (deflated 75%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/qian/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/qian/qian_embeddings.pkl (deflated 90%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/pbmed/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/pbmed/pbmed_embeddings.pkl (deflated 85%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/aminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/aminer/aminer_embeddings.pkl (deflated 93%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/arnetminer/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/arnetminer/arnetminer_embeddings.pkl (deflated 96%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42/ (stored 0%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42/info.txt (deflated 19%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42/vq_50.pt (deflated 8%)
#   adding: embeddings/aminer_arnetminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_arnetminer_kisti_pbmed_qian_zbmath_seed_42/encoder_50.pt (deflated 8%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/ (stored 0%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/kisti/ (stored 0%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/kisti/kisti_embeddings.pkl (deflated 82%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/zbmath/ (stored 0%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/zbmath/zbmath_embeddings.pkl (deflated 76%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/qian/ (stored 0%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/qian/qian_embeddings.pkl (deflated 89%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/pbmed/ (stored 0%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/pbmed/pbmed_embeddings.pkl (deflated 84%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/aminer/ (stored 0%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/aminer/aminer_embeddings.pkl (deflated 93%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/arnetminer/ (stored 0%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/arnetminer/arnetminer_embeddings.pkl (deflated 96%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_kisti_pbmed_qian_zbmath_seed_42/ (stored 0%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_kisti_pbmed_qian_zbmath_seed_42/info.txt (deflated 15%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_kisti_pbmed_qian_zbmath_seed_42/vq_50.pt (deflated 8%)
#   adding: embeddings/aminer_kisti_pbmed_qian_zbmath/codebook_size_128_layer_2_pretrain_on_aminer_kisti_pbmed_qian_zbmath_seed_42/encoder_50.pt (deflated 8%)
# Архив embeddings_all.zip создан. Скачайте его через интерфейс Kaggle.
